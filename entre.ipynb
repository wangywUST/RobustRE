# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline
import joblib
import numpy as np
import scipy.special as sp
from transformers import LukeTokenizer, LukeForEntityPairClassification
import json
import torch
from tqdm import trange
import pdb
import random
from collections import Counter

tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")

nlp = pipeline("ner", model=model, tokenizer=tokenizer, device = 0)
example = "Berlin"

ner_results = nlp(example)
print(ner_results)
# Out:
# [{'entity': 'B-LOC', 'score': 0.99975425, 'index': 1, 'word': 'Berlin', 'start': 0, 'end': 6}]

# %%
# This function loads the dataset .json file and produce the list containing the relation extraction instances.
def load_examples(dataset_file):
    with open(dataset_file, "r") as f:
        data = json.load(f)

    examples = []
    for i, item in enumerate(data):
        tokens = item["token"]
        token_spans = dict(
            subj=(item["subj_start"], item["subj_end"] + 1),
            obj=(item["obj_start"], item["obj_end"] + 1)
        )

        if token_spans["subj"][0] < token_spans["obj"][0]:
            entity_order = ("subj", "obj")
        else:
            entity_order = ("obj", "subj")

        text = ""
        cur = 0
        char_spans = {}
        for target_entity in entity_order:
            token_span = token_spans[target_entity]
            text += " ".join(tokens[cur : token_span[0]])
            if text:
                text += " "
            char_start = len(text)
            text += " ".join(tokens[token_span[0] : token_span[1]])
            char_end = len(text)
            char_spans[target_entity] = (char_start, char_end)
            text += " "
            cur = token_span[1]
        text += " ".join(tokens[cur:])
        text = text.rstrip()

        examples.append(dict(
            text=text,
            entity_spans=[tuple(char_spans["subj"]), tuple(char_spans["obj"])],
            label=item["relation"],
            entity_type = (item['subj_type'], item['obj_type']),
        ))

    return examples

def overlap(range_a, range_ls):
    for range_ in range_ls:
        if range_[0] <= range_a[0] <= range_[1] or range_a[0] <= range_[0] <= range_a[1]:
            return True
    
    return False

def printREInstance(text, subj_span, obj_span, subj_type, obj_type):
    if subj_span[0] < obj_span[0]:
        new_text = text[:subj_span[0]] + '@' + text[subj_span[0] : subj_span[1]] + '@' + '(subj type:' + subj_type + ')' + \
                    text[subj_span[1] : obj_span[0]] + '#' + text[obj_span[0] : obj_span[1]] + '#' + '(obj type:' + obj_type + ')' + \
                    text[obj_span[1] : ]
    else:
        new_text = text[:obj_span[0]] + '#' + text[obj_span[0] : obj_span[1]] + '#'  + '(obj type:' + obj_type + ')' + \
                    text[obj_span[1] : subj_span[0]] + '@' + text[subj_span[0] : subj_span[1]] + '@' + '(subj type:' + subj_type + ')' + \
                    text[subj_span[1] : ]
        
    print(new_text)

# %%
test_examples = load_examples("test.json")
re_test_examples = load_examples("test_re.json")
rev_test_examples = load_examples("test_rev.json")
printREInstance(test_examples[0]['text'], 
                test_examples[0]['entity_spans'][0], test_examples[0]['entity_spans'][1],
                test_examples[0]['entity_type'][0], test_examples[0]['entity_type'][1],
               )

subj_per_name_ls = list(
        [
        test_examples[id_]['text'][
            test_examples[id_]['entity_spans'][0][0] 
            : 
            test_examples[id_]['entity_spans'][0][1]
            ].upper()
        for id_ in range(len(test_examples))
        if 
        (test_examples[id_]['entity_type'][0] == 'PERSON'
        )
        ]
)

subj_org_name_ls = list(
        [
        test_examples[id_]['text'][
            test_examples[id_]['entity_spans'][0][0] 
            : 
            test_examples[id_]['entity_spans'][0][1]
            ].upper()
        for id_ in range(len(test_examples))
        if 
        (test_examples[id_]['entity_type'][0] == 'ORGANIZATION'
        )
        ]
)

print('distinct number of tacred subj person names: ', len(set(subj_per_name_ls)))
print('distinct number of tacred subj organization names: ',len(set(subj_org_name_ls)))

re_subj_per_name_ls = list(
        [
        re_test_examples[id_]['text'][
            re_test_examples[id_]['entity_spans'][0][0] 
            : 
            re_test_examples[id_]['entity_spans'][0][1]
            ].upper()
        for id_ in range(len(re_test_examples))
        if 
        (re_test_examples[id_]['entity_type'][0] == 'PERSON'
        )
        ]
)

re_subj_org_name_ls = list(
        [
        re_test_examples[id_]['text'][
            re_test_examples[id_]['entity_spans'][0][0] 
            : 
            re_test_examples[id_]['entity_spans'][0][1]
            ].upper()
        for id_ in range(len(re_test_examples))
        if 
        (re_test_examples[id_]['entity_type'][0] == 'ORGANIZATION'
        )
        ]
)

print('distinct number of retacred subj person names: ', len(set(re_subj_per_name_ls)))
print('distinct number of retacred subj organization names: ',len(set(re_subj_org_name_ls)))

rev_subj_per_name_ls = list(
        [
        rev_test_examples[id_]['text'][
            rev_test_examples[id_]['entity_spans'][0][0] 
            : 
            rev_test_examples[id_]['entity_spans'][0][1]
            ].upper()
        for id_ in range(len(rev_test_examples))
        if 
        (rev_test_examples[id_]['entity_type'][0] == 'PERSON'
        )
        ]
)

rev_subj_org_name_ls = list(
        [
        rev_test_examples[id_]['text'][
            rev_test_examples[id_]['entity_spans'][0][0] 
            : 
            rev_test_examples[id_]['entity_spans'][0][1]
            ].upper()
        for id_ in range(len(rev_test_examples))
        if 
        (rev_test_examples[id_]['entity_type'][0] == 'ORGANIZATION'
        )
        ]
)

print('distinct number of tacrev subj person names: ', len(set(rev_subj_per_name_ls)))
print('distinct number of tacrev subj organization names: ',len(set(rev_subj_org_name_ls)))
# Out:
# He has served as a policy aide to the late U.S. Senator Alan Cranston , as National Issues Director for the 2004 presidential campaign of Congressman Dennis Kucinich , as a co-founder of @Progressive Democrats of America@(subj type:ORGANIZATION) and as a member of the #international policy department#(obj type:ORGANIZATION) at the RAND Corporation think tank before all that .
# distinct number of tacred subj person names:  238
# distinct number of tacred subj organization names:  204
# distinct number of retacred subj person names:  217
# distinct number of retacred subj organization names:  177
# distinct number of tacrev subj person names:  238
# distinct number of tacrev subj organization names:  204

# %%
subj_overlap_ls = []
batch_size = 128
for batch_start_idx in trange(0, len(test_examples), batch_size):
    batch_examples = test_examples[batch_start_idx:batch_start_idx + batch_size]
    texts = [example["text"] for example in batch_examples]
    entity_spans = [example["entity_spans"][0] for example in batch_examples]
    entity_types = [example["entity_type"][0] for example in batch_examples]
    
    ner_result_ls = nlp(texts)
    ner_per_ls = [[(ner_['start'], ner_['end']) for ner_ in entity_ls_ if 'PER' in ner_['entity']] for entity_ls_ in ner_result_ls]
    ner_org_ls = [[(ner_['start'], ner_['end']) for ner_ in entity_ls_ if 'ORG' in ner_['entity']] for entity_ls_ in ner_result_ls]

    overlap_flag = [
        False
        or (overlap(entity_spans[i_], ner_per_ls[i_]) and entity_types[i_] == 'PERSON')
        or (overlap(entity_spans[i_], ner_org_ls[i_]) and entity_types[i_] == 'ORGANIZATION')
        for i_ in range(len(batch_examples))
    ]
    
    subj_overlap_ls.extend([i_ + batch_start_idx for i_ in range(len(batch_examples)) if overlap_flag[i_]])

print(len(subj_overlap_ls), len(test_examples))

obj_overlap_ls = []
for batch_start_idx in trange(0, len(test_examples), batch_size):
    batch_examples = test_examples[batch_start_idx:batch_start_idx + batch_size]
    texts = [example["text"] for example in batch_examples]
    entity_spans = [example["entity_spans"][1] for example in batch_examples]
    entity_types = [example["entity_type"][1] for example in batch_examples]
    
    ner_result_ls = nlp(texts)
    ner_per_ls = [[(ner_['start'], ner_['end']) for ner_ in entity_ls_ if 'PER' in ner_['entity']] for entity_ls_ in ner_result_ls]
    ner_org_ls = [[(ner_['start'], ner_['end']) for ner_ in entity_ls_ if 'ORG' in ner_['entity']] for entity_ls_ in ner_result_ls]

    overlap_flag = [
        False
        or (overlap(entity_spans[i_], ner_per_ls[i_]) and entity_types[i_] == 'PERSON')
        or (overlap(entity_spans[i_], ner_org_ls[i_]) and entity_types[i_] == 'ORGANIZATION')
        for i_ in range(len(batch_examples))
    ]
    
    obj_overlap_ls.extend([i_ + batch_start_idx for i_ in range(len(batch_examples)) if overlap_flag[i_]])

print(len(obj_overlap_ls), len(test_examples))
print(len(set(obj_overlap_ls).union(set(subj_overlap_ls))), len(test_examples))
# Out:
# 100%|██████████| 122/122 [03:21<00:00,  1.66s/it]
# 10145 15509
# 100%|██████████| 122/122 [03:21<00:00,  1.65s/it]
# 4912 15509
# 11661 15509

# %%
from collections import Counter

named_organization_name_ls = [
                test_examples[id_]['text'][
                    test_examples[id_]['entity_spans'][0][0] 
                    : 
                    test_examples[id_]['entity_spans'][0][1]
                    ].upper()
                for id_ in subj_overlap_ls
                if test_examples[id_]['entity_type'][0] == 'ORGANIZATION'
                ] + \
                [
                test_examples[id_]['text'][
                    test_examples[id_]['entity_spans'][1][0] 
                    : 
                    test_examples[id_]['entity_spans'][1][1]
                    ].upper()
                for id_ in obj_overlap_ls
                if test_examples[id_]['entity_type'][1] == 'ORGANIZATION'
                ]

print('number of distinct named organization: ', len(set(named_organization_name_ls)))
print('counter of named organization: ', Counter(named_organization_name_ls))
print()

named_person_name_ls = [
        test_examples[id_]['text'][
            test_examples[id_]['entity_spans'][0][0] 
            : 
            test_examples[id_]['entity_spans'][0][1]
            ].upper()
        for id_ in subj_overlap_ls
        if test_examples[id_]['entity_type'][0] == 'PERSON'
        ] + \
        [
        test_examples[id_]['text'][
            test_examples[id_]['entity_spans'][1][0] 
            : 
            test_examples[id_]['entity_spans'][1][1]
            ].upper()
        for id_ in obj_overlap_ls
        if test_examples[id_]['entity_type'][1] == 'PERSON'
        ]


print('number of distinct named person: ', len(set(named_person_name_ls)))
print('counter of named person: ', Counter(named_person_name_ls))
# Out:
# number of distinct named organization:  966
# counter of named organization:  Counter({'CORPORATE LIBRARY': 243, 'SHOPPERTRAK': 240, 'ALICO': 236, 'ADF': 215, 'NATIONAL RESTAURANT ASSOCIATION': 212, 'PATA': 194, 'COUNTRYWIDE': 192, 'NATIONAL URBAN LEAGUE': 179, 'CHINA CHARITY FEDERATION': 167, 'NATIONAL DEVELOPMENT AND REFORM COMMISSION': 166, 'NDRC': 128, 'PACIFIC ASIA TRAVEL ASSOCIATION': 122, 'NATIONAL CONGRESS OF AMERICAN INDIANS': 118, 'PROGRESSIVE DEMOCRATS OF AMERICA': 102, 'OANA': 100, 'NATIONAL TAIWAN SYMPHONY ORCHESTRA': 99, 'NATIONAL ENERGY ADMINISTRATION': 94, 'AMERICAN FREE PRESS': 93, 'TPI': 93, 'UASR': 85, 'LIHOP': 82, 'MENIL COLLECTION': 81, 'NDA': 81, 'SYCAMORE': 77, 'NTSO': 75, 'PDA': 71, 'URBAN LEAGUE': 66, 'SEMEN GRESIK': 63, 'AFP': 56, 'PSIA': 47, 'LOOKING CLOUD': 43, 'KOCH FOODS': 43, 'COUNTRYWIDE FINANCIAL': 42, 'AAUW': 39, 'COUNTRYWIDE FINANCIAL CORP.': 38, 'NRA': 36, 'NUCLEAR DECOMMISSIONING AUTHORITY': 36, 'AIG': 36, 'TRIBECA ENTERPRISES': 34, 'AMERICAN ASSOCIATION OF UNIVERSITY WOMEN': 33, 'NEW FABRIS': 29, 'NEA': 29, 'HKI': 29, 'LOOSE CHANGE': 28, 'CCF': 27, 'UN': 27, 'AUSTRALIAN DEFENCE FORCE': 26, 'HELEN KELLER INTERNATIONAL': 25, 'MEF': 25, 'METLIFE': 24, 'ORGANIZATION OF ASIA-PACIFIC NEWS AGENCIES': 23, 'KOCH FOODS INC.': 23, 'AIA': 22, 'AUSTRALIAN DEFENSE FORCE': 21, 'MYANMAR EQUESTRIAN FEDERATION': 21, 'UNITED NATIONS': 18, 'CHONGQING MUNICIPAL JUDICIAL BUREAU': 18, 'COASTAL CONSERVATION LEAGUE': 17, 'DEFENCE FORCE': 17, 'PROFESSIONAL SKI INSTRUCTORS OF AMERICA': 16, 'NCAI': 16, 'AMERICAN LIFE INSURANCE COMPANY': 16, 'ORGANIZATION OF ASIA PACIFIC NEWS AGENCIES': 15, 'RED CROSS SOCIETY OF CHINA': 15, 'NAACP': 15, 'RED CROSS': 15, 'ORGANISATION OF ASIA-PACIFIC NEWS AGENCIES': 14, 'HELOISE': 14, 'MIHOP': 14, 'UNITED ASSOCIATION FOR STUDIES AND RESEARCH': 13, 'HOLLISTER INC.': 13, 'U.N.': 13, 'CONGRESS': 13, 'THIRD GUARD DIVISION': 12, 'BANK OF AMERICA': 12, 'PLURIBUS CAPITAL MANAGEMENT': 11, 'SAP': 11, 'TAIWAN SYMPHONY ORCHESTRA': 11, 'KBR': 10, 'SEC': 10, 'THE CHINA CHARITY FEDERATION': 9, 'THE MENIL COLLECTION': 9, 'CENTRAL AMERICAN PARLIAMENT': 9, 'CUSTOMS ENFORCEMENT': 9, 'ORACLE': 9, 'STATE DEPARTMENT': 9, 'TALIBAN': 9, 'HAMAS': 9, 'LC': 8, 'ORGANIZATION OF ASIA-PACIFIC NEWS AGENCY': 8, 'THAI PETROCHEMICAL INDUSTRY PLC': 8, 'UNITED SOLUTIONS AND SERVICES': 8, 'ACSE': 8, 'UNITED NEGRO COLLEGE FUND': 8, 'UNWTO': 8, 'XINHUA': 8, 'MGE': 8, 'FBI': 8, 'AMERICAN LIFE INSURANCE CO.': 8, 'TEMPAT PELELANGAN IKAN': 7, 'COUNTRYWIDE FINANCIAL CORPORATION': 7, 'POVERTY AND SOCIAL IMPACT ANALYSIS OF REFORMS': 7, 'SECURITY COUNCIL': 7, 'INTERNATIONAL COMMITTEE OF THE RED CROSS': 7, 'IRS': 7, 'AP': 7, 'LA LINEA': 7, 'THE NATIONAL RESTAURANT ASSOCIATION': 6, 'PACIFIC-ASIA TRAVEL ASSOCIATION': 6, 'COUNTRYWIDE FINANCIAL CORP': 6, 'QATALYS , INC': 6, 'MEDIO ORIENTE NIR ROSEN': 6, 'COUNCIL FOR CULTURAL AFFAIRS': 6, 'CIT': 6, 'MCA': 6, 'RCSC': 6, 'HALLIBURTON': 6, 'WORLD BANK': 6, 'HOUSE': 6, 'PACKARD': 6, 'AMERICAN LIFE INSURANCE CO': 6, 'UNIVERSITY OF CALGARY': 6, 'YOUNG PATRIOTS': 6, 'CEPHALON': 6, 'AMERICAN INTERNATIONAL GROUP': 6, 'COUNTRYWIDE HOME LOANS': 5, "GAY MEN 'S HEALTH CRISIS": 5, 'PLURIBUS': 5, 'SYCAMORE SOFTWARE SOLUTIONS': 5, 'CFC': 5, 'PARLACEN': 5, 'ALLIED DEMOCRATIC FORCES': 5, 'TPIPL': 5, 'POPULAR MECHANICS': 5, 'INTERNATIONAL COMMITTEE': 5, 'BANK OF AMERICA CORP.': 5, 'NYU': 5, "NEW LIFE CHILDREN 'S REFUGE": 5, 'TIMES': 5, 'CHURCH OF SCIENTOLOGY': 5, 'ICRC': 5, 'NEW YORK TIMES': 5, 'MUSEUM OF MODERN ART': 5, 'BBC': 5, "INTERMEDIATE PEOPLE 'S COURT": 5, 'UNIVERSITY OF WASHINGTON': 5, 'TRUTH MOVEMENT': 5, '`` YOUNG PATRIOTS': 5, 'COUNTRYWIDE BANK': 4, 'ORGANIZATION OF ASIA - PACIFIC NEWS AGENCIES': 4, 'BEDBUG CENTRAL': 4, 'THE MENIL COLLECTION 1515 SUL ROSS': 4, 'DANCE THEATRE OF HARLEM': 4, 'NUL': 4, 'STATE DEVELOPMENT AND REFORM COMMISSION': 4, 'THE GOOD BROKER , LLC': 4, 'NEW AMERICA FOUNDATION': 4, 'SKY BLUE': 4, 'ASSOCIATED PRESS': 4, 'YOUTUBE': 4, 'AGENCY FOR INTERNATIONAL DEVELOPMENT': 4, 'UNIVERSITY OF CALIFORNIA': 4, 'EPF': 4, 'NP ...
# number of distinct named person:  1257
# counter of named person:  Counter({'BIBI': 230, 'GRAHAM': 215, 'CHEN TAO': 212, 'AHMED RASHID': 183, 'WEN QIANG': 182, 'NIR ROSEN': 177, 'MARK FISHER': 166, 'PIEDRA': 143, 'SAMUDIO': 143, 'RICHARD GAGE': 137, 'CHARLES BLE GOUDE': 129, 'RUBEN VAN ASSOUW': 127, 'VAGNI': 124, 'ALAN GROSS': 121, 'XIE CAIPING': 119, 'AQUASH': 112, 'MATTEO MESSINA DENARO': 104, 'EUGENIO VAGNI': 103, 'LAURA SILSBY': 100, 'ALESSI': 100, 'SHAH ABDUL AZIZ': 99, 'CERNIGLIA': 97, 'YOUSSOUFOU BAMBA': 96, 'JOHN GRAHAM': 92, 'JAMIE LEIGH JONES': 91, 'BLE GOUDE': 87, 'CHIAFARI': 85, 'CHRISTOPHER BOLLYN': 83, 'HELOISE': 82, 'RASHID': 77, 'SARAH KUNSTLER': 73, 'KNOX': 71, 'BENJAMIN CHERTOFF': 69, 'WEN': 68, 'DWORIN': 66, 'AMANDA KNOX': 64, 'ADELA DWORIN': 63, 'DANIELS': 62, 'ELIZA SAMUDIO': 61, 'GONZALEZ': 60, 'ILAN RAMON': 57, 'MARIO GONZALEZ': 57, 'VLADIMIR LADYZHENSKIY': 56, 'HAGEMO': 56, 'LOMAX': 54, 'MICHAEL LOMAX': 53, 'JUPP': 50, 'CRAIG RANKE': 49, 'MEREDITH KERCHER': 43, 'ELOISE SPOONER': 40, 'SODINI': 40, 'SANDRA HEROLD': 39, 'CAROL DANIELS': 38, 'NORRIS CHURCH MAILER': 38, 'NASH': 38, 'GEORGE SODINI': 37, 'NELL MINOW': 37, 'WAYNE A. HOLST': 35, 'HEROLD': 35, 'ANNIE MAE AQUASH': 34, 'MESSINA DENARO': 34, 'RUBEN': 33, 'PATRICIA GONZALEZ': 31, 'LANGE': 30, 'ASSAF RAMON': 30, 'PAUL HODGSON': 28, 'BRUNO': 27, 'GROSS': 26, 'ROSEN': 26, 'MIETTINEN': 26, 'WILLIAM KUNSTLER': 24, 'ANNA MAE': 23, 'ANDREW LANGE': 22, 'BILL MARTIN': 22, 'JOSEPH CERNIGLIA': 21, 'ASIA BIBI': 21, 'SILSBY': 21, 'BALDINO': 20, 'ZHANG GUOBAO': 20, 'OBAMA': 20, 'TRAVIS': 19, 'MARC MORIAL': 18, 'ZHOU XIAOYA': 18, 'JONES': 17, 'SHELBY': 17, 'CLARK': 17, 'TERRY JUPP': 16, 'FRANK CHIAFARI': 16, 'ANNA MAE AQUASH': 16, 'KUNSTLER': 16, 'MAILER': 16, 'OUATTARA': 16, 'GAGE': 16, 'CHEN': 15, 'KOREY ROWE': 15, 'TAMAIHIA LYNAE MOORE': 15, 'XIE': 15, 'ENZO': 15, 'JUDY GROSS': 15, 'MCCAIN': 15, 'ANNA MAE PICTOU AQUASH': 14, 'FRANK BALDINO JR.': 14, 'ESTHER-ETHY MAMANE': 14, 'ANDREW E. LANGE': 14, 'ANGELO MOZILO': 14, 'RAMON': 13, 'MICHAEL CHERTOFF': 13, 'ARLO LOOKING CLOUD': 13, 'ABU SAYYAF': 13, 'SHERROD': 13, 'HUANG DAIQIANG': 13, 'PAULIINA MIETTINEN': 12, 'TIMO KAUKONEN': 12, 'DYLAN AVERY': 12, 'THEDA CLARK': 12, 'TRUDY': 12, 'PUELLO': 12, 'ALMENA LOMAX': 11, 'NATALIE HAGEMO': 11, 'ALBERT LANGE': 11, 'PATRICK': 11, 'ZHAO LIMING': 11, 'GBAGBO': 11, 'BUSH': 11, 'BAMBA': 10, 'JOSEPH I. LANGE': 10, 'WILLIAM A. LANGE': 10, 'CHARLA NASH': 10, 'KERCHER': 10, 'SOUZA': 10, 'LADYZHENSKIY': 9, 'CLAUDINE': 9, 'WAYNE HOLST': 9, 'ANDREW E LANGE': 9, 'KAREN LANGE': 9, 'ADAM LANGE': 9, 'SOLLECITO': 9, 'DYLAN': 9, 'FATTAH': 9, 'CLAUDIE MAMANE': 8, 'ALAN P. GROSS': 8, 'TRAVIS THE CHIMP': 8, 'QUENTIN FABRIS': 8, 'NORMAN MAILER': 8, 'ALASSANE OUATTARA': 8, 'RAMSAY': 8, 'EMILY': 8, 'TAMAIHIA': 7, 'PAULIINA': 7, 'RENE PIEDRA': 7, 'ELIZA': 7, 'KIP HOLLISTER': 7, 'ANNA MAE PICTOU': 7, 'JOHN': 7, 'ASHIQ MASIH': 7, 'CAIN': 7, 'ECOFFEY': 7, 'BHATTI': 7, 'JOHN MURPHY': 7, 'CURT KNOX': 7, 'FISHER': 7, 'LO PICCOLO': 7, 'ZARDARI': 7, 'SUN QIN': 7, 'ABDUL AZIZ': 6, 'ALAN P GROSS': 6, 'HERMAN CAIN': 6, 'RAFFAELE SOLLECITO': 6, 'PRACHAI': 6, 'MOZILO': 6, 'CRAIG': 6, 'EDDA MELLAS': 6, 'JOHN GAY': 6, 'GORDON RAMSAY': 6, 'HUDSON RIEHLE': 6, 'AHMAD MUKHLIS YUSUF': 6, 'MARSHALL': 6, 'TIM CARPENTER': 6, 'CASTRO': 6, 'AVERY': 6, 'TRIMBLE': 6, 'BRIAN MOSKOWITZ': 6, 'STEVEN JONES': 6, 'SPOONER': 5, 'CHERTOFF': 5, 'DWORINS': 5, 'TERRY': 5, 'LIU QI': 5, 'MOHAMMED': 5, 'ZHOU HAIBIN': 5, 'EDWARDS': 5, 'JEFFERSON KEEL': 5, 'ANGELO R MOZILO': 5, 'BARACK OBAMA': 5, 'PRACHAI LEOPHAIRATANA': 5, 'ABELARD': 5, 'MIKE CHERTOFF': 4, 'CLAUDINE MAMANE': 4, 'JOEL DENARO': 4, 'ALVIN DANIELS': 4, 'FRANK BALDINO JR': 4, 'DENARO': 4, 'ILAN': 4, 'ROGER SPOONER': 4, 'JEANNE CAMPBELL': 4, 'JACKLEY': 4, 'JOHN KOLDOWSKI': 4, 'GIULIANI': 4, 'ADI AMIT': 4, 'PROVENZANO': 4, 'MORALES': 4, 'MARY JEAN LACABA': 4, 'SHEN LONGYUAN': 4, 'ROSAS': 4, 'FRANCES M. JEWELS': 4, 'SALAAM': 4, 'GU JUN': 4, 'DAVIS': 4, 'LAURENT GBAGBO': 4, 'RAMPONE': 4, 'SALMAN TASEER': 4, 'RANKE': 4,  ...

# %%
subj_no_overlap_ls = list(set(range(len(test_examples))) - set(subj_overlap_ls))
obj_no_overlap_ls = list(set(range(len(test_examples))) - set(obj_overlap_ls))

no_named_organization_name_ls = [
                test_examples[id_]['text'][
                    test_examples[id_]['entity_spans'][0][0] 
                    : 
                    test_examples[id_]['entity_spans'][0][1]
                    ].upper()
                for id_ in subj_no_overlap_ls
                if test_examples[id_]['entity_type'][0] == 'ORGANIZATION'
                ] + \
                [
                test_examples[id_]['text'][
                    test_examples[id_]['entity_spans'][1][0] 
                    : 
                    test_examples[id_]['entity_spans'][1][1]
                    ].upper()
                for id_ in obj_no_overlap_ls
                if test_examples[id_]['entity_type'][1] == 'ORGANIZATION'
                ]

no_named_person_name_ls = [
                test_examples[id_]['text'][
                    test_examples[id_]['entity_spans'][0][0] 
                    : 
                    test_examples[id_]['entity_spans'][0][1]
                    ].upper()
                for id_ in subj_no_overlap_ls
                if test_examples[id_]['entity_type'][0] == 'PERSON'
                ] + \
                [
                test_examples[id_]['text'][
                    test_examples[id_]['entity_spans'][1][0] 
                    : 
                    test_examples[id_]['entity_spans'][1][1]
                    ].upper()
                for id_ in obj_no_overlap_ls
                if test_examples[id_]['entity_type'][1] == 'PERSON'
                ]

bad_org_name = ['ASSOCIATION', 'IT', 'HER', 'GROUP', 'SHE', 'THE FACTORY', 'EMAIL', 'HIS', 'COMPANY', 'ITS', 'HER', 'HIS', 'HOUSE', 'THE', 'HIM']
good_per_name = ['SCRAPBLOG', 'PIEDRA', 'SYCAMORE', 'HELOISE', 'PIEDRA', 'ALESSI', 'AQUASH', 'CERNIGLIA', 'ANNA MAE', 'SEMEN GRESIK', 'ANDREW LANGE', 'MESSINA DENARO', 'RICHARD GAGE', 
                'NORRIS CHURCH MAILER', 'ASIA BIBI', 'FABRIS',  'NELL MINOW', 'PAUL HODGSON']
bad_per_name = list(set(no_named_person_name_ls) - set(good_per_name))
print('the bad person entities that cannot be replaced with other persons: ', bad_per_name)
# Out:
# the bad person entities that cannot be replaced with other persons:  ['HELPFUL HINTER', 'SHE', 'BURNS', 'BOFA', 'CASTRO', 'KALINEN', 'JUAREZ', 'ST. PAUL', 'SEARS', 'A SENIOR OFFICIAL', 'CREEK', 'LENOIR', 'PANEER BURJI', 'AWAITING THE VERDICT WITH OTHER FAMILY MEMBERS', "''", 'FRANKO PIZZA', 'TOM HAYDEN', 'PAKISTAN', 'THE BOY', 'DE MENILS', 'NIDAL', 'LEVY', 'KNOX', 'AL-QADA', 'HELL', 'ARMY OF THE MAHDI', 'VICTOR', 'MAN', 'KOBE', 'HER HUSBAND', 'TRAPANI', 'WOMAN', 'MASCARA', 'BERMAS', 'BABY', 'LOUIS GHOST', 'DEPUTY POLICE CHIEF', 'THE KILLER', 'HUSBAND', 'SON CITGO', 'PAUL', 'BELO HORIZONTE', 'REDSTONE', 'NASSER', 'PIHAKNYA SELAKU PENYELENGGARA MENGAKU BANGGA BISA MELAHIRKAN BINTANG-BINTANG MASA DEPAN DARI KALANGAN MASYARAKAT', 'DAVID', 'FINN', 'CODE PINK', 'THE AMERICAN', 'AN AMERICAN', 'SUSHI RAN', 'BROWN', 'CONTRACTOR', 'MUSLIM', 'JOHN GALT', 'MEMBER', 'DOE', 'LOOSE CHANGE', 'SHERROD', 'JACKSON', 'TAU', 'COSA NOSTRA', 'PLANTANUS', 'TOURISTS', 'BUD LITE', 'BEHROOZ', 'WORKER', 'PEOPLE', 'LAL MASJID', 'BANK OF AMERICA CORP', 'MOM', 'ZAZZLE', 'SISTER', 'LA LINEA', 'HIM', 'LAMESTREAM', 'WEST', 'ZIRH', 'SAMBOL', 'MAILER', 'BROTHER', 'HERS', 'MOZILO', 'HELLO', 'CHRISTMAS', 'LATINO', 'SON', 'YISRAEL', 'HELEN KELLER INTERNATIONAL', 'DE IRAK', 'BETH SHALOM', 'KING', 'AMY GOODMAN', 'THELONEBEDOUIN', 'BERLINER BAROCK SOLISTEN', 'BUKIT ASAM', 'BEN HUR', 'BIOLOGIST', 'MAXFIELD', 'JERUSALEM , SEPT 14 , 2009', 'SKUD', 'DVDS', 'PASTOR', 'PACIFIC INVESTMENT MANAGEMENT CO', 'JDEVELOPER', 'HER', 'SIMILIE', 'LOWE', "GANG `` GODMOTHER ''", 'VAN WYCK', 'BANK OF AMERICA', 'PEARLMAN', 'DESILIENS', 'CHIEF', 'HE', 'A MAN', 'CHUNYUN', 'OSAMA-APPROVED AL-QUEADA', 'ABU SAYYAF', 'MUJAHID', 'GALLAGHER', 'BOY', 'YOUNG PILOT', 'AXELROD', 'HANUKKAH', 'LOVING MAILER', 'GENERAL RE', 'RUSSIAN MAN', 'ICONIC FIGHTER PILOT', 'CHILD', 'ROBERT DE NIRO', 'RUSSELL 2000', 'BUSH', 'CHEF', 'ROTHKO CHAPEL', 'JFK', 'HEPATITIS', 'RAND MCNALLY', 'THE LEADER OF THE GROUP OF AMERICANS', 'KULAYIGYE', 'A CHRISTIAN WOMAN', 'BLACK', 'SPVS', 'HIS FATHER', 'RICHARDSON', 'FRI', 'PILOT', 'BLYSKAL', 'CHRISTIAN WOMAN', 'THORP', 'GBAGBO', 'ITALY', 'NEW FABRIS', 'UNIVERSITY OF MARYLAND', 'MASSE', 'MINOW', '-RRB- --', 'FARIS JAWAD', 'COUNTRYWIDES', 'PATSY', 'MURDER', 'ROSS', 'PINTO', 'YOUNG PATRIOT', 'RICH MURPHY', 'HAHAHAHAHAHAHA', 'AIR EVAC EMS , INC', 'KMAQ', 'CATHOLIC', 'ALI', 'LAWYER', 'OUATTARA', 'BIN LADEN', '46', 'RICK MURPHY', 'ARTEMIDE', 'LATIN', 'LAWMAKER', 'MATHMETICIAN', 'GODMOTHER', 'ABU ALWAFA', 'HIS', 'NIELSEN']

# %%
bad_example_per_ls = ['BANK OF AMERICA']
bad_example_org_ls = ['HIS']
example_bad_id_ls = list(
        [
        id_
        for id_ in range(len(test_examples))
        if 
        (test_examples[id_]['entity_type'][0] == 'ORGANIZATION'
        and test_examples[id_]['text'][
            test_examples[id_]['entity_spans'][0][0] 
            : 
            test_examples[id_]['entity_spans'][0][1]
            ].upper() in bad_example_org_ls
        )
        or
        (test_examples[id_]['entity_type'][0] == 'PERSON'
        and test_examples[id_]['text'][
            test_examples[id_]['entity_spans'][0][0] 
            : 
            test_examples[id_]['entity_spans'][0][1]
            ].upper() in bad_example_per_ls
        )
        or
        (test_examples[id_]['entity_type'][1] == 'ORGANIZATION'
        and test_examples[id_]['text'][
            test_examples[id_]['entity_spans'][1][0] 
            : 
            test_examples[id_]['entity_spans'][1][1]
            ].upper() in bad_example_org_ls
        )
        or
        (test_examples[id_]['entity_type'][1] == 'PERSON'
        and test_examples[id_]['text'][
            test_examples[id_]['entity_spans'][1][0] 
            : 
            test_examples[id_]['entity_spans'][1][1]
            ].upper() in bad_example_per_ls
        )
        ]
)
print(example_bad_id_ls)

for id_ in example_bad_id_ls:
    print('instanced id: ', id_)
    printREInstance(test_examples[id_]['text'], 
                    test_examples[id_]['entity_spans'][0], test_examples[id_]['entity_spans'][1],
                    test_examples[id_]['entity_type'][0], test_examples[id_]['entity_type'][1],
                   )
    print()
# Out:
# [4190, 5949, 7523, 7606, 7919, 8939, 10909, 12135, 13112]
# instanced id:  4190
# It traveled to Rice University , where de Menil and #his#(obj type:ORGANIZATION) wife , Dominique de Menil , who later founded the @Menil Collection@(subj type:ORGANIZATION) , ran the art museum .
#
# instanced id:  5949
# AJ - complete psychopath , mentally ill DRG - weasel and snake oil salesmen of the nth degree #Fetzer#(obj type:PERSON) - Loony toons SJ - ignorant of facts , and morally compromising for the sake of @his@(subj type:ORGANIZATION) argument .
#
# instanced id:  7523
# He figured that he would sell his home before the interest rate on the loan , taken out from @Countrywide Financial@(subj type:ORGANIZATION) , now owned by #Bank of America#(obj type:PERSON) , reset at a higher level .
#
# instanced id:  7606
# To him the walls of #his#(obj type:ORGANIZATION) prison are invisible , and @he@(subj type:ORGANIZATION) believes himself to be free .
#
# instanced id:  7919
# when Avery had to calm him down by touching @his@(subj type:ORGANIZATION) shoulder , which was quite possibly the most akward moment since #Rocky#(obj type:ORGANIZATION) 's and Apollo Creed 's man hug on a beach in Rocky III .
#
# instanced id:  8939
# `` When I was watching @Loose Change@(subj type:PERSON) with a friend of mine - he happens to work for a company that helps build the Boeing airplanes and they said that when the engines completely disappeared and were destroyed , #his#(obj type:ORGANIZATION) response was , excuse my French - bullshit !
#
# instanced id:  10909
# I was going to nominate Bobbie Balsamo , but in hindsight he has also been left in the dumpster , relegated to blatant milking of @his@(subj type:ORGANIZATION) flock through auto-renewing `` Chip In '' applets which scrape in enough money to keep #his#(obj type:ORGANIZATION) Bud Lite supply limping along .
#
# instanced id:  12135
# I know @Christopher Bollyn@(subj type:PERSON) , have talked to him on the phone and via e-mail exchanges , and I 've read most of #his#(obj type:ORGANIZATION) works , and I believe he is the same way .
#
# instanced id:  13112
# @His@(subj type:ORGANIZATION) followers come to my campus and talk about how awesome Kepler is and how #Obama#(obj type:PERSON) is a Nazi .

# %%
subj_final_id_ls = list(
        [
        id_
        for id_ in range(len(test_examples))
        if 
        (test_examples[id_]['entity_type'][0] == 'ORGANIZATION'
        and test_examples[id_]['text'][
            test_examples[id_]['entity_spans'][0][0] 
            : 
            test_examples[id_]['entity_spans'][0][1]
            ].upper() not in bad_org_name
        )
        or
        (test_examples[id_]['entity_type'][0] == 'PERSON'
        and test_examples[id_]['text'][
            test_examples[id_]['entity_spans'][0][0] 
            : 
            test_examples[id_]['entity_spans'][0][1]
            ].upper() not in bad_per_name
        )
        ]
)

obj_final_id_ls = list(
        [
        id_
        for id_ in range(len(test_examples))
        if 
        (test_examples[id_]['entity_type'][1] == 'ORGANIZATION'
        and test_examples[id_]['text'][
            test_examples[id_]['entity_spans'][1][0] 
            : 
            test_examples[id_]['entity_spans'][1][1]
            ].upper() not in bad_org_name
        )
        or
        (test_examples[id_]['entity_type'][1] == 'PERSON'
        and test_examples[id_]['text'][
            test_examples[id_]['entity_spans'][1][0] 
            : 
            test_examples[id_]['entity_spans'][1][1]
            ].upper() not in bad_per_name
        )
        ]
)

print('number of instances having subject for replacements: ', len(subj_final_id_ls))
print('number of instances having object for replacements: ', len(obj_final_id_ls))
# Out:
# number of instances having subject for replacements:  10840
# number of instances having object for replacements:  5368

# %%
from collections import Counter

final_organization_name_ls = [
                test_examples[id_]['text'][
                    test_examples[id_]['entity_spans'][0][0] 
                    : 
                    test_examples[id_]['entity_spans'][0][1]
                    ].upper()
                for id_ in subj_final_id_ls
                if test_examples[id_]['entity_type'][0] == 'ORGANIZATION'
                ] + \
                [
                test_examples[id_]['text'][
                    test_examples[id_]['entity_spans'][1][0] 
                    : 
                    test_examples[id_]['entity_spans'][1][1]
                    ].upper()
                for id_ in obj_final_id_ls
                if test_examples[id_]['entity_type'][1] == 'ORGANIZATION'
                ]

print('number of instances having organization for replacements: ', len(final_organization_name_ls))
print('number of distinct organization names for replacements: ', len(set(final_organization_name_ls)))
print('number of distinct organization names for replacements: ', Counter(final_organization_name_ls))

final_person_name_ls = [
                test_examples[id_]['text'][
                    test_examples[id_]['entity_spans'][0][0] 
                    : 
                    test_examples[id_]['entity_spans'][0][1]
                    ].upper()
                for id_ in subj_final_id_ls
                if test_examples[id_]['entity_type'][0] == 'PERSON'
                ] + \
                [
                test_examples[id_]['text'][
                    test_examples[id_]['entity_spans'][1][0] 
                    : 
                    test_examples[id_]['entity_spans'][1][1]
                    ].upper()
                for id_ in obj_final_id_ls
                if test_examples[id_]['entity_type'][1] == 'PERSON'
                ]

print(len(final_person_name_ls))
print(len(set(final_person_name_ls)))
print(Counter(final_person_name_ls))
# Out:
# number of instances having organization for replacements:  7681
# number of distinct organization names for replacements:  1308
# number of distinct organization names for replacements:  Counter({'SHOPPERTRAK': 271, 'CORPORATE LIBRARY': 247, 'ADF': 245, 'ALICO': 238, 'COUNTRYWIDE': 215, 'NATIONAL RESTAURANT ASSOCIATION': 212, 'PATA': 199, 'NATIONAL URBAN LEAGUE': 182, 'CHINA CHARITY FEDERATION': 167, 'NATIONAL DEVELOPMENT AND REFORM COMMISSION': 166, 'NDRC': 128, 'LIHOP': 124, 'PACIFIC ASIA TRAVEL ASSOCIATION': 122, 'NATIONAL CONGRESS OF AMERICAN INDIANS': 118, 'PROGRESSIVE DEMOCRATS OF AMERICA': 107, 'OANA': 106, 'TPI': 101, 'NATIONAL TAIWAN SYMPHONY ORCHESTRA': 99, 'NATIONAL ENERGY ADMINISTRATION': 94, 'AMERICAN FREE PRESS': 93, 'SYCAMORE': 87, 'UASR': 85, 'MENIL COLLECTION': 84, 'NDA': 81, 'NORRIS CHURCH': 79, 'PSIA': 76, 'NTSO': 75, 'PDA': 73, 'LOOKING CLOUD': 73, 'URBAN LEAGUE': 70, 'LOOSE CHANGE': 69, 'ARLO LOOKING CLOUD': 69, 'SEMEN GRESIK': 68, 'AFP': 56, 'KOCH FOODS': 43, 'AAUW': 43, 'COUNTRYWIDE FINANCIAL': 42, 'COUNTRYWIDE FINANCIAL CORP.': 38, 'NRA': 37, 'AIG': 37, 'NUCLEAR DECOMMISSIONING AUTHORITY': 36, 'TRIBECA ENTERPRISES': 34, 'MEF': 34, 'AMERICAN ASSOCIATION OF UNIVERSITY WOMEN': 33, 'NEW FABRIS': 30, 'NEA': 29, 'HKI': 29, 'UN': 28, 'CCF': 27, 'AUSTRALIAN DEFENCE FORCE': 26, 'TALIBAN': 26, 'METLIFE': 26, 'HELEN KELLER INTERNATIONAL': 25, 'NORRIS CHURCH MAILER': 25, 'HIGH POINT CHURCH': 23, 'ORGANIZATION OF ASIA-PACIFIC NEWS AGENCIES': 23, 'KOCH FOODS INC.': 23, 'AIA': 22, 'AUSTRALIAN DEFENSE FORCE': 21, 'MYANMAR EQUESTRIAN FEDERATION': 21, 'HELOISE': 20, 'MIHOP': 19, 'UNITED NATIONS': 18, 'CHONGQING MUNICIPAL JUDICIAL BUREAU': 18, 'COASTAL CONSERVATION LEAGUE': 17, 'SOCIAL IMPACT ANALYSIS': 17, 'DEFENCE FORCE': 17, 'PROFESSIONAL SKI INSTRUCTORS OF AMERICA': 16, 'NCAI': 16, 'AMERICAN LIFE INSURANCE COMPANY': 16, 'RED CROSS': 16, 'ORGANIZATION OF ASIA PACIFIC NEWS AGENCIES': 15, 'HE': 15, 'RED CROSS SOCIETY OF CHINA': 15, 'NAACP': 15, 'ORGANISATION OF ASIA-PACIFIC NEWS AGENCIES': 14, 'CENTRAL AMERICAN PARLIAMENT': 14, 'CONGRESS': 14, 'UNITED ASSOCIATION FOR STUDIES AND RESEARCH': 13, 'HOLLISTER INC.': 13, 'U.N.': 13, 'XINHUA': 13, 'THIRD GUARD DIVISION': 12, 'BANK OF AMERICA': 12, 'PLURIBUS CAPITAL MANAGEMENT': 11, 'SAP': 11, 'TAIWAN SYMPHONY ORCHESTRA': 11, 'GROSS': 11, 'LC': 10, 'ERP': 10, 'USING POVERTY AND SOCIAL IMPACT ANALYSIS': 10, 'DYLAN AVERY': 10, 'KBR': 10, 'A-ADOMESTIC LIFE': 10, 'SEC': 10, 'THE CHINA CHARITY FEDERATION': 9, 'THE MENIL COLLECTION': 9, 'ANADARKO': 9, 'CUSTOMS ENFORCEMENT': 9, 'ORACLE': 9, 'STATE DEPARTMENT': 9, 'HAMAS': 9, 'ORGANIZATION OF ASIA-PACIFIC NEWS AGENCY': 8, 'HUNTINGTON LIBRARY': 8, 'THAI PETROCHEMICAL INDUSTRY PLC': 8, 'UNITED SOLUTIONS AND SERVICES': 8, 'PIEDRA': 8, 'ACSE': 8, 'POVERTY AND SOCIAL ANALYSIS': 8, 'UNITED NEGRO COLLEGE FUND': 8, 'UNWTO': 8, 'MGE': 8, 'FBI': 8, 'HALLIBURTON': 8, 'AMERICAN LIFE INSURANCE CO.': 8, 'MINAS GERAIS': 8, 'BROTHERS': 8, 'CEPHALON': 8, 'TEMPAT PELELANGAN IKAN': 7, 'NO PLANERS': 7, 'COUNTRYWIDE FINANCIAL CORPORATION': 7, 'POVERTY AND SOCIAL IMPACT ANALYSIS OF REFORMS': 7, 'CIT': 7, 'BELLY OF THE GREEN BIRD': 7, 'SECURITY COUNCIL': 7, 'INTERNATIONAL COMMITTEE OF THE RED CROSS': 7, 'IRS': 7, 'AP': 7, 'LA LINEA': 7, 'THE NATIONAL RESTAURANT ASSOCIATION': 6, 'PACIFIC-ASIA TRAVEL ASSOCIATION': 6, 'COUNTRYWIDE FINANCIAL CORP': 6, 'QATALYS , INC': 6, 'MEDIO ORIENTE NIR ROSEN': 6, 'THE GOOD BROKER , LLC': 6, 'COUNCIL FOR CULTURAL AFFAIRS': 6, 'MCA': 6, 'GENERAL ASSEMBLY': 6, 'RCSC': 6, 'JUSTICE DEPARTMENT': 6, 'WORLD BANK': 6, 'STATE MEDIA': 6, 'PACKARD': 6, 'AMERICAN LIFE INSURANCE CO': 6, 'ARMY': 6, 'UNIVERSITY OF CALGARY': 6, 'YOUNG PATRIOTS': 6, 'FED': 6, 'AMERICAN INTERNATIONAL GROUP': 6, 'COUNTRYWIDE HOME LOANS': 5, "GAY MEN 'S HEALTH CRISIS": 5, 'PLURIBUS': 5, 'SYCAMORE SOFTWARE SOLUTIONS': 5, 'CFC': 5, 'PARLACEN': 5, 'ALLIED DEMOCRATIC FORCES': 5, 'TPIPL': 5, 'DEFENSE': 5, 'TRUTH': 5, 'POPULAR MECHANICS': 5, 'INTERNATIONAL COMMITTEE': 5, 'BANK OF AMERICA CORP.': 5, 'NYU': 5, 'YOUTUBE': 5, "NEW LIFE CHILDREN 'S REFUGE": 5, 'PARLIAMENT': 5, 'TIMES': 5, 'CHURCH OF S ...
# 8527
# 1231
# Counter({'BIBI': 230, 'GRAHAM': 215, 'CHEN TAO': 212, 'AHMED RASHID': 183, 'WEN QIANG': 182, 'NIR ROSEN': 177, 'MARK FISHER': 166, 'PIEDRA': 158, 'ALESSI': 154, 'SAMUDIO': 143, 'RICHARD GAGE': 138, 'CHARLES BLE GOUDE': 129, 'RUBEN VAN ASSOUW': 127, 'VAGNI': 124, 'ALAN GROSS': 121, 'AQUASH': 121, 'XIE CAIPING': 119, 'HELOISE': 106, 'MATTEO MESSINA DENARO': 104, 'EUGENIO VAGNI': 103, 'CERNIGLIA': 102, 'LAURA SILSBY': 100, 'SHAH ABDUL AZIZ': 99, 'YOUSSOUFOU BAMBA': 96, 'JOHN GRAHAM': 92, 'JAMIE LEIGH JONES': 91, 'BLE GOUDE': 87, 'CHIAFARI': 85, 'CHRISTOPHER BOLLYN': 83, 'RASHID': 77, 'SARAH KUNSTLER': 73, 'BENJAMIN CHERTOFF': 69, 'WEN': 68, 'DWORIN': 66, 'AMANDA KNOX': 64, 'ADELA DWORIN': 63, 'DANIELS': 62, 'ELIZA SAMUDIO': 61, 'GONZALEZ': 60, 'ILAN RAMON': 57, 'MARIO GONZALEZ': 57, 'VLADIMIR LADYZHENSKIY': 56, 'HAGEMO': 56, 'LOMAX': 54, 'MICHAEL LOMAX': 53, 'JUPP': 50, 'CRAIG RANKE': 49, 'MEREDITH KERCHER': 43, 'ELOISE SPOONER': 40, 'SODINI': 40, 'NORRIS CHURCH MAILER': 39, 'SANDRA HEROLD': 39, 'CAROL DANIELS': 38, 'NASH': 38, 'GEORGE SODINI': 37, 'NELL MINOW': 37, 'MESSINA DENARO': 36, 'WAYNE A. HOLST': 35, 'HEROLD': 35, 'ANNIE MAE AQUASH': 34, 'RUBEN': 33, 'PATRICIA GONZALEZ': 31, 'LANGE': 30, 'ASSAF RAMON': 30, 'PAUL HODGSON': 28, 'BRUNO': 27, 'GROSS': 26, 'ANNA MAE': 26, 'ROSEN': 26, 'MIETTINEN': 26, 'SYCAMORE': 25, 'ANDREW LANGE': 24, 'WILLIAM KUNSTLER': 24, 'ASIA BIBI': 22, 'BILL MARTIN': 22, 'JOSEPH CERNIGLIA': 21, 'SILSBY': 21, 'BALDINO': 20, 'ZHANG GUOBAO': 20, 'OBAMA': 20, 'TRAVIS': 19, 'MARC MORIAL': 18, 'ZHOU XIAOYA': 18, 'JONES': 17, 'SHELBY': 17, 'CLARK': 17, 'TERRY JUPP': 16, 'FRANK CHIAFARI': 16, 'ANNA MAE AQUASH': 16, 'KUNSTLER': 16, 'GAGE': 16, 'CHEN': 15, 'KOREY ROWE': 15, 'TAMAIHIA LYNAE MOORE': 15, 'XIE': 15, 'ENZO': 15, 'JUDY GROSS': 15, 'MCCAIN': 15, 'ANNA MAE PICTOU AQUASH': 14, 'SCRAPBLOG': 14, 'FRANK BALDINO JR.': 14, 'ESTHER-ETHY MAMANE': 14, 'ANDREW E. LANGE': 14, 'ANGELO MOZILO': 14, 'RAMON': 13, 'MICHAEL CHERTOFF': 13, 'ARLO LOOKING CLOUD': 13, 'HUANG DAIQIANG': 13, 'PAULIINA MIETTINEN': 12, 'TIMO KAUKONEN': 12, 'DYLAN AVERY': 12, 'THEDA CLARK': 12, 'TRUDY': 12, 'PUELLO': 12, 'ALMENA LOMAX': 11, 'NATALIE HAGEMO': 11, 'ALBERT LANGE': 11, 'PATRICK': 11, 'ZHAO LIMING': 11, 'BAMBA': 10, 'JOSEPH I. LANGE': 10, 'WILLIAM A. LANGE': 10, 'CHARLA NASH': 10, 'KERCHER': 10, 'SOUZA': 10, 'LADYZHENSKIY': 9, 'CLAUDINE': 9, 'WAYNE HOLST': 9, 'ANDREW E LANGE': 9, 'KAREN LANGE': 9, 'ADAM LANGE': 9, 'FABRIS': 9, 'SOLLECITO': 9, 'DYLAN': 9, 'FATTAH': 9, 'CLAUDIE MAMANE': 8, 'ALAN P. GROSS': 8, 'TRAVIS THE CHIMP': 8, 'QUENTIN FABRIS': 8, 'NORMAN MAILER': 8, 'ALASSANE OUATTARA': 8, 'RAMSAY': 8, 'EMILY': 8, 'TAMAIHIA': 7, 'PAULIINA': 7, 'RENE PIEDRA': 7, 'ELIZA': 7, 'KIP HOLLISTER': 7, 'ANNA MAE PICTOU': 7, 'JOHN': 7, 'ASHIQ MASIH': 7, 'CAIN': 7, 'ECOFFEY': 7, 'BHATTI': 7, 'JOHN MURPHY': 7, 'CURT KNOX': 7, 'FISHER': 7, 'LO PICCOLO': 7, 'ZARDARI': 7, 'SUN QIN': 7, 'SEMEN GRESIK': 6, 'ABDUL AZIZ': 6, 'ALAN P GROSS': 6, 'HERMAN CAIN': 6, 'RAFFAELE SOLLECITO': 6, 'PRACHAI': 6, 'CRAIG': 6, 'EDDA MELLAS': 6, 'JOHN GAY': 6, 'GORDON RAMSAY': 6, 'HUDSON RIEHLE': 6, 'AHMAD MUKHLIS YUSUF': 6, 'MARSHALL': 6, 'TIM CARPENTER': 6, 'AVERY': 6, 'TRIMBLE': 6, 'BRIAN MOSKOWITZ': 6, 'STEVEN JONES': 6, 'SPOONER': 5, 'CHERTOFF': 5, 'DWORINS': 5, 'TERRY': 5, 'LIU QI': 5, 'MOHAMMED': 5, 'ZHOU HAIBIN': 5, 'EDWARDS': 5, 'JEFFERSON KEEL': 5, 'ANGELO R MOZILO': 5, 'BARACK OBAMA': 5, 'PRACHAI LEOPHAIRATANA': 5, 'ABELARD': 5, 'MIKE CHERTOFF': 4, 'CLAUDINE MAMANE': 4, 'JOEL DENARO': 4, 'ALVIN DANIELS': 4, 'FRANK BALDINO JR': 4, 'DENARO': 4, 'ILAN': 4, 'ROGER SPOONER': 4, 'JEANNE CAMPBELL': 4, 'JACKLEY': 4, 'JOHN KOLDOWSKI': 4, 'GIULIANI': 4, 'ADI AMIT': 4, 'PROVENZANO': 4, 'MORALES': 4, 'MARY JEAN LACABA': 4, 'SHEN LONGYUAN': 4, 'ROSAS': 4, 'FRANCES M. JEWELS': 4, 'SALAAM': 4, 'GU JUN': 4, 'DAVIS': 4, 'LAURENT GBAGBO': 4, 'RAMPONE': 4, 'SALMAN TASEER': 4, 'RANKE': 4, 'DAVID RAY GRIFFIN': 4, 'CAROL STEVENS': 4, 'JIM EDWARDS': 4, 'ARNOLD': 4, 'ZHAO XURI' ...

# %%
final_id_ls = list(set(subj_final_id_ls + obj_final_id_ls))

final_relation_ls = [
        test_examples[id_]['label']
        for id_ in list(set(subj_final_id_ls + obj_final_id_ls))
        ]

print('number of instances for replacements: ', len(final_relation_ls))
print('number of distinct relations for replacements: ', len(set(final_relation_ls)))

label_counter = Counter(final_relation_ls)
print('counter of relation labels for replacements: ', label_counter)
print()

minor_class = [
    class_
    for class_ in list(set(final_relation_ls))
    if label_counter[class_] < 20
]
print('classes of small number of instances: ', minor_class)
# Out:
# number of instances for replacements:  12193
# number of distinct relations for replacements:  42
# counter of relation labels for replacements:  Counter({'no_relation': 9247, 'per:title': 410, 'org:top_members/employees': 346, 'per:employee_of': 264, 'org:alternate_names': 213, 'per:age': 169, 'per:cities_of_residence': 129, 'per:origin': 114, 'org:country_of_headquarters': 107, 'per:countries_of_residence': 104, 'per:parents': 83, 'org:city_of_headquarters': 82, 'per:charges': 80, 'org:founded_by': 68, 'org:parents': 62, 'per:spouse': 62, 'per:stateorprovinces_of_residence': 57, 'per:siblings': 51, 'per:other_family': 51, 'org:stateorprovince_of_headquarters': 51, 'org:subsidiaries': 44, 'per:cause_of_death': 40, 'per:date_of_death': 39, 'org:founded': 36, 'per:children': 32, 'org:members': 31, 'per:religion': 31, 'per:schools_attended': 30, 'org:website': 24, 'per:city_of_death': 23, 'org:member_of': 18, 'org:number_of_employees/members': 17, 'org:shareholders': 13, 'per:alternate_names': 11, 'per:stateorprovince_of_death': 11, 'org:political/religious_affiliation': 9, 'per:date_of_birth': 8, 'per:country_of_death': 8, 'per:stateorprovince_of_birth': 6, 'per:country_of_birth': 5, 'per:city_of_birth': 5, 'org:dissolved': 2})
#
# classes of small number of instances:  ['per:country_of_death', 'org:number_of_employees/members', 'per:alternate_names', 'per:date_of_birth', 'per:stateorprovince_of_birth', 'per:city_of_birth', 'org:political/religious_affiliation', 'org:dissolved', 'org:member_of', 'org:shareholders', 'per:country_of_birth', 'per:stateorprovince_of_death']

# %%
final_id_resample_ls = final_id_ls + [i_ for i_ in final_id_ls if test_examples[i_]['label'] in minor_class] * 2
joblib.dump((final_id_resample_ls, subj_final_id_ls, obj_final_id_ls), 'final_id_resample_ls.output')
# Out:
# ['final_id_resample_ls.output']
